# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
filepath = "Resources/IMDB_Movies_2021.db"
engine = create_engine(f"sqlite:///{filepath}")
df = pd.read_sql("SELECT AUTHOR, TITLE, REVIEW, RATING FROM REVIEWS", engine)
df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                          Not Bad\n
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                            Great White=Jaws Lite\n
# 3                kuarinofu                     Bare-bones killer shark film\n
# 4     Horror_Flick_Fanatic                Terrible story, dialogue, and CGI\n
# ...                    ...                                                ...
# 5445         suryajijvania                                       More Parts\n
# 5446      shishirkmr-82243                           It's a fantastic movie\n
# 5447        moizsyed-07601                            Awesome out standing!\n
# 5448        samun_shrestha                                             EPIC\n
# 5449       mmuradali-65680                      The best DC movie till date\n
#
# ...

# %%
null_counts = df['RATING'].isnull()
null_counts

clean_df = df.dropna().copy()
clean_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                          Not Bad\n
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                            Great White=Jaws Lite\n
# 3                kuarinofu                     Bare-bones killer shark film\n
# 4     Horror_Flick_Fanatic                Terrible story, dialogue, and CGI\n
# ...                    ...                                                ...
# 5445         suryajijvania                                       More Parts\n
# 5446      shishirkmr-82243                           It's a fantastic movie\n
# 5447        moizsyed-07601                            Awesome out standing!\n
# 5448        samun_shrestha                                             EPIC\n
# 5449       mmuradali-65680                      The best DC movie till date\n
#
# ...

# %%
clean_df['TITLE'].replace('\n', '', regex=True, inplace=True)
clean_df['REVIEW'].replace('\n', '', regex=True, inplace=True)
clean_df['REVIEW'].replace(',', '',regex = True, inplace = True)
clean_df['REVIEW'].replace("'", '',regex = True, inplace = True)

clean_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5445         suryajijvania                                         More Parts
# 5446      shishirkmr-82243                             It's a fantastic movie
# 5447        moizsyed-07601                              Awesome out standing!
# 5448        samun_shrestha                                               EPIC
# 5449       mmuradali-65680                        The best DC movie till date
#
# ...

# %%
clean_df = clean_df.drop_duplicates(subset='AUTHOR', keep='first')
clean_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5420         suryajijvania                                         More Parts
# 5421      shishirkmr-82243                             It's a fantastic movie
# 5422        moizsyed-07601                              Awesome out standing!
# 5423        samun_shrestha                                               EPIC
# 5424       mmuradali-65680                        The best DC movie till date
#
# ...

# %%
clean_df.index = np.arange(1, len(clean_df) + 1)

clean_df["AUTHOR_ID"] = clean_df.index 

#clean_df = clean_df.pop('AUTHOR_ID')
clean_df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                     AUTHOR                                              TITLE  \
# 1          margarida-44311                                            Not Bad
# 2                 joemay-2   What are all the bad reviews about is it a wo...
# 3                     nebk                              Great White=Jaws Lite
# 4                kuarinofu                       Bare-bones killer shark film
# 5     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# ...

# %%
engine = create_engine('sqlite:///clean_reviews_data.db', echo=True)
sqlite_connection = engine.connect()

# %%
sqlite_table = "imdbreviews"
clean_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2021-08-23 07:44:05,006 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("imdbreviews")
# 2021-08-23 07:44:05,008 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-23 07:44:05,010 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("imdbreviews")
# 2021-08-23 07:44:05,012 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-23 07:44:05,017 INFO sqlalchemy.engine.Engine
# CREATE TABLE imdbreviews (
# 	"index" BIGINT,
# 	"AUTHOR" TEXT,
# 	"TITLE" TEXT,
# 	"REVIEW" TEXT,
# 	"RATING" FLOAT,
# 	"AUTHOR_ID" BIGINT
# )
#
#
# 2021-08-23 07:44:05,018 INFO sqlalchemy.engine.Engine [no key 0.00130s] ()
# 2021-08-23 07:44:05,022 INFO sqlalchemy.engine.Engine COMMIT
# 2021-08-23 07:44:05,023 INFO sqlalchemy.engine.Engine CREATE INDEX ix_imdbreviews_index ON imdbreviews ("index")
# 2021-08-23 07:44:05,025 INFO sqlalchemy.engine.Engine [no key 0.00159s] ()
# 2021-08-23 07:44:05,031 INFO sqlalchemy.engine.Engine COMMIT
# 2021-08-23 07:44:05,039 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
clean_df.to_csv("imdbreviews.csv", index = False)

# %%
author_data = clean_df[["AUTHOR_ID","AUTHOR"]]
author_data.set_index('AUTHOR_ID')
author_data =author_data.sort_index(ascending = True)
author_data
# Out:
#       AUTHOR_ID                AUTHOR
# 1             1       margarida-44311
# 2             2              joemay-2
# 3             3                  nebk
# 4             4             kuarinofu
# 5             5  Horror_Flick_Fanatic
# ...         ...                   ...
# 4674       4674         suryajijvania
# 4675       4675      shishirkmr-82243
# 4676       4676        moizsyed-07601
# 4677       4677        samun_shrestha
# 4678       4678       mmuradali-65680
#
# [4678 rows x 2 columns]

# %%
author_data.to_csv("authors.csv", index = False)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5433/author')
connection = engine.connect()

# %%
author_data = pd.read_sql("SELECT * FROM authors", connection)
author_data
# Out:
#       AUTHOR_ID                AUTHOR
# 0             1       margarida-44311
# 1             2              joemay-2
# 2             3                  nebk
# 3             4             kuarinofu
# 4             5  Horror_Flick_Fanatic
# ...         ...                   ...
# 4673       4674         suryajijvania
# 4674       4675      shishirkmr-82243
# 4675       4676        moizsyed-07601
# 4676       4677        samun_shrestha
# 4677       4678       mmuradali-65680
#
# [4678 rows x 2 columns]

# %%
imdb_data = clean_df[["AUTHOR_ID","AUTHOR"]]
author_data.set_index('AUTHOR_ID')
author_data =author_data.sort_index(ascending = True)
author_data

# %%
#from sqlalchemy import create_engine

# %%
sqlite_connection.close()
