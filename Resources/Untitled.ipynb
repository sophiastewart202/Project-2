# %%
import pandas as pd
from sqlalchemy import create_engine, Table, Column, Integer, MetaData
import numpy as np
from sqlalchemy.ext.automap import automap_base

# %%
filepath = "../clean_reviews_data.db"
engine = create_engine(f"sqlite:///{filepath}")
data_df = pd.read_sql('SELECT AUTHOR, TITLE, REVIEW, RATING FROM "IMDB_Reviews"', engine)
data_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5327         suryajijvania                                         More Parts
# 5328      shishirkmr-82243                             It's a fantastic movie
# 5329        moizsyed-07601                              Awesome out standing!
# 5330        samun_shrestha                                               EPIC
# 5331       mmuradali-65680                        The best DC movie till date
#
# ...

# %%
data_df["AUTHOR_ID"] = data_df.index +1
data_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5327         suryajijvania                                         More Parts
# 5328      shishirkmr-82243                             It's a fantastic movie
# 5329        moizsyed-07601                              Awesome out standing!
# 5330        samun_shrestha                                               EPIC
# 5331       mmuradali-65680                        The best DC movie till date
#
# ...

# %%
data_df.to_csv("IMDB_Reviews.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3910a123e44c> in <module>
# ----> 1 data_df.to_csv("IMDB_Reviews.csv", index = False)
#
# NameError: name 'data_df' is not defined

# %%
author_data = data_df[["AUTHOR_ID","AUTHOR"]]
author_data.set_index('AUTHOR_ID')
author_data =author_data.sort_index(ascending = True)
author_data
# Out:
#       AUTHOR_ID                AUTHOR
# 0             1       margarida-44311
# 1             2              joemay-2
# 2             3                  nebk
# 3             4             kuarinofu
# 4             5  Horror_Flick_Fanatic
# ...         ...                   ...
# 5327       5328         suryajijvania
# 5328       5329      shishirkmr-82243
# 5329       5330        moizsyed-07601
# 5330       5331        samun_shrestha
# 5331       5332       mmuradali-65680
#
# [5332 rows x 2 columns]

# %%
author_data.to_csv("authors.csv", index = False)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5433/author')
connection = engine.connect()

# %%
author_data = pd.read_sql("SELECT * FROM authors", connection)
author_data
# Out:
#       AUTHOR_ID                AUTHOR
# 0             1       margarida-44311
# 1             2              joemay-2
# 2             3                  nebk
# 3             4             kuarinofu
# 4             5  Horror_Flick_Fanatic
# ...         ...                   ...
# 5327       5328         suryajijvania
# 5328       5329      shishirkmr-82243
# 5329       5330        moizsyed-07601
# 5330       5331        samun_shrestha
# 5331       5332       mmuradali-65680
#
# [5332 rows x 2 columns]
