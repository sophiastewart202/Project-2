# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
filepath = "Resources/IMDB_Movies_2021.db"
engine = create_engine(f"sqlite:///{filepath}")
df = pd.read_sql("SELECT ID, AUTHOR, TITLE, REVIEW, RATING FROM REVIEWS", engine)
df
# Out:
#         ID                AUTHOR  \
# 0        1       margarida-44311
# 1        2              joemay-2
# 2        3                  nebk
# 3        4             kuarinofu
# 4        5  Horror_Flick_Fanatic
# ...    ...                   ...
# 5445  5446         suryajijvania
# 5446  5447      shishirkmr-82243
# 5447  5448        moizsyed-07601
# 5448  5449        samun_shrestha
# 5449  5450       mmuradali-65680
#
#                                                   TITLE  \
# 0                                             Not Bad\n
# 1      What are all the bad reviews about is it a wo...
# 2                               Great White=Jaws Lite\n
# 3                        Bare-bones killer shark film\n
# 4                   Terrible story, dialogue, and CGI\n
# ...                                                 ...
# 5445                                       More Parts\n
# 5446                           It's a fantastic movie\n
# ...

# %%
null_counts = df['RATING'].isnull()
null_counts

clean_df = df.dropna().copy()
clean_df
# Out:
#         ID                AUTHOR  \
# 0        1       margarida-44311
# 1        2              joemay-2
# 2        3                  nebk
# 3        4             kuarinofu
# 4        5  Horror_Flick_Fanatic
# ...    ...                   ...
# 5445  5446         suryajijvania
# 5446  5447      shishirkmr-82243
# 5447  5448        moizsyed-07601
# 5448  5449        samun_shrestha
# 5449  5450       mmuradali-65680
#
#                                                   TITLE  \
# 0                                             Not Bad\n
# 1      What are all the bad reviews about is it a wo...
# 2                               Great White=Jaws Lite\n
# 3                        Bare-bones killer shark film\n
# 4                   Terrible story, dialogue, and CGI\n
# ...                                                 ...
# 5445                                       More Parts\n
# 5446                           It's a fantastic movie\n
# ...

# %%
clean_df['TITLE'].replace('\n', '', regex=True, inplace=True)
clean_df['REVIEW'].replace('\n', '', regex=True, inplace=True)
clean_df
# Out:
#         ID                AUTHOR  \
# 0        1       margarida-44311
# 1        2              joemay-2
# 2        3                  nebk
# 3        4             kuarinofu
# 4        5  Horror_Flick_Fanatic
# ...    ...                   ...
# 5445  5446         suryajijvania
# 5446  5447      shishirkmr-82243
# 5447  5448        moizsyed-07601
# 5448  5449        samun_shrestha
# 5449  5450       mmuradali-65680
#
#                                                   TITLE  \
# 0                                               Not Bad
# 1      What are all the bad reviews about is it a wo...
# 2                                 Great White=Jaws Lite
# 3                          Bare-bones killer shark film
# 4                     Terrible story, dialogue, and CGI
# ...                                                 ...
# 5445                                         More Parts
# 5446                             It's a fantastic movie
# ...

# %%
engine = create_engine('sqlite:///clean_reviews_data.db', echo=True)
sqlite_connection = engine.connect()

# %%
sqlite_table = "IMDB_Reviews"
clean_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2021-08-21 13:46:32,832 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("IMDB_Reviews")
# 2021-08-21 13:46:32,833 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-21 13:46:32,835 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("IMDB_Reviews")
# 2021-08-21 13:46:32,835 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-21 13:46:32,838 INFO sqlalchemy.engine.Engine
# CREATE TABLE "IMDB_Reviews" (
# 	"index" BIGINT,
# 	"ID" BIGINT,
# 	"AUTHOR" TEXT,
# 	"TITLE" TEXT,
# 	"REVIEW" TEXT,
# 	"RATING" FLOAT
# )
#
#
# 2021-08-21 13:46:32,840 INFO sqlalchemy.engine.Engine [no key 0.00232s] ()
# 2021-08-21 13:46:32,979 INFO sqlalchemy.engine.Engine COMMIT
# 2021-08-21 13:46:32,980 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_IMDB_Reviews_index" ON "IMDB_Reviews" ("index")
# 2021-08-21 13:46:32,981 INFO sqlalchemy.engine.Engine [no key 0.00113s] ()
# 2021-08-21 13:46:33,090 INFO sqlalchemy.engine.Engine COMMIT
# ...

# %%
sqlite_connection.close()
