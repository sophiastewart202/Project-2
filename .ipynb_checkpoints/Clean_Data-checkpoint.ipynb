# %%
import pandas as pd
import numpy as np

# %%
pathone = '../Project-1_Resources/aggr/VAERSDATA.csv'
pathtwo = '../Project-1_Resources/aggr/VAERSSYMPTOMS.csv'
paththree = '../Project-1_Resources/aggr/VAERSVAX.csv'

# %%
# Drop duplicates
df1 = pd.read_csv(pathone, low_memory=False)
data_df = df1.drop_duplicates(subset=['VAERS_ID'], keep='first', ignore_index=True)
data_df = data_df.loc[data_df['AGE_YRS']>=12.00]
data_df
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX    RPT_DATE  \
# 1         413802  01/01/2011    CO     13.0     13.0      NaN   F  01/01/2011
# 2         413803  01/01/2011    TN     67.0     67.0      NaN   F  01/01/2011
# 3         413804  01/01/2011    MN     62.0     62.0      NaN   F  01/01/2011
# 6         413808  01/01/2011    WA     65.0     65.0      NaN   F  01/01/2011
# 7         413830  01/01/2011    TN     76.0     76.0      NaN   M  12/28/2010
# ...          ...         ...   ...      ...      ...      ...  ..         ...
# 798180   1442854  07/02/2021    FL     17.0     17.0      NaN   F         NaN
# 798181   1442855  07/02/2021    RI     52.0     52.0      NaN   F         NaN
# 798182   1442856  07/02/2021    CA     37.0     37.0      NaN   F         NaN
# 798183   1442857  07/02/2021    DE     69.0     69.0      NaN   F         NaN
# 798184   1442858  07/02/2021    ME     46.0     46.0      NaN   F         NaN
#
#                                              SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 1       My daughter's hands and feet are red, purple, ...  NaN  ...      No
# 2       Patient had itchy rash develop on neck and chest.  NaN  ...      no
# 3       Swelling, itching, redness, pain, rash on neck...  NaN  ...    none
# 6       Onset of Shingles rash after having received t...  NaN  ...      no
# 7       Patient developed Guillain Barr� after receivi...  NaN  ...     NaN
# ...                                                   ...  ...  ...     ...
# 798180            Error: Wrong Dose of Vaccine - Too Low-  NaN  ...     NaN
# 798181  I am not certain if this outcome is related to...  NaN  ...    none
# 798182  Systemic: Dizziness / Lightheadness-Mild, Syst...  NaN  ...     NaN
# 798183  Prior to vaccine, my Hips were only mildly art...  NaN  ...     NaN
# 798184  1 or 2 days after vaccination administration -...  NaN  ...    None
#
#                                                   HISTORY  \
# 1                                                    None
# 2                                   lymphoma in remission
# 3       sulfa, dust, mold, weeds, trees, grasses, cats...
# 6                                                    none
# 7                                                     NaN
# ...                                                   ...
# 798180                                                NaN
# 798181                                mild hypothyroidism
# 798182                                                NaN
# 798183  Arthritis, Acid Reflux,Graves' Disease, Depres...
# 798184                                               None
#
#                                                 PRIOR_VAX SPLTTYPE  FORM_VERS  \
# 1                                                     NaN      NaN          1
# 2                                                     NaN      NaN          1
# 3                                                     NaN      NaN          1
# 6                                                     NaN      NaN          1
# 7                                                     NaN      NaN          1
# ...                                                   ...      ...        ...
# 798180                                                NaN      NaN          2
# 798181  frozen shoulder following influenza vaccine  O...      NaN          2
# 798182                                                NaN      NaN          2
# 798183                                                NaN      NaN          2
# 798184                                                NaN      NaN          2
#
#        TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 1              NaN          NaN       NaN         NaN
# 2              NaN          NaN       NaN         NaN
# 3              NaN          NaN       NaN         NaN
# 6              NaN          NaN       NaN         NaN
# 7              NaN          NaN       NaN         NaN
# ...            ...          ...       ...         ...
# 798180  07/02/2021          NaN       NaN         NaN
# 798181  07/02/2021          NaN         Y         NaN
# 798182  07/02/2021          NaN       NaN         NaN
# 798183  07/02/2021          NaN         Y         NaN
# 798184  07/02/2021          NaN       NaN         NaN
#
#                          ALLERGIES
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 6                              NaN
# 7                              NaN
# ...                            ...
# 798180                         NaN
# 798181  chlorhexidine scrub (rash)
# 798182                         NaN
# 798183                  None known
# 798184          Sulfa & penicillin
#
# [603029 rows x 35 columns]

# %%
df2 = pd.read_csv(pathtwo, low_memory=False)
symptoms_df = df2.drop_duplicates(subset=['VAERS_ID'], keep='first', ignore_index=True)
symptoms_df
# Out:
#         VAERS_ID                           SYMPTOM1  SYMPTOMVERSION1  \
# 0         413801                   Gait disturbance             13.1
# 1         413802                           Cyanosis             13.1
# 2         413803                      Rash pruritic             13.1
# 3         413804                           Erythema             13.1
# 4         413805         Body temperature increased             13.1
# ...          ...                                ...              ...
# 798175   1442854        Incorrect dose administered             24.0
# 798176   1442855  Acoustic stimulation tests normal             24.0
# 798177   1442856                             Crying             24.0
# 798178   1442857                  Blood test normal             24.0
# 798179   1442858                    Breast swelling             24.0
#
#                         SYMPTOM2  SYMPTOMVERSION2                   SYMPTOM3  \
# 0       Injection site haematoma             13.1        Injection site pain
# 1                       Erythema             13.1            Laboratory test
# 2                            NaN              NaN                        NaN
# 3                           Pain             13.1                   Pruritus
# 4                         Crying             13.1               Diet refusal
# ...                          ...              ...                        ...
# 798175                       NaN              NaN                        NaN
# 798176                 Dizziness             24.0                    Fatigue
# 798177                 Dizziness             24.0           Hyperventilation
# 798178        Bone marrow oedema             24.0  C-reactive protein normal
# 798179         Breast tenderness             24.0         Menstrual disorder
#
#         SYMPTOMVERSION3                 SYMPTOM4  SYMPTOMVERSION4  \
# 0                  13.1  Injection site swelling             13.1
# 1                  13.1      Skin discolouration             13.1
# 2                   NaN                      NaN              NaN
# 3                  13.1                     Rash             13.1
# 4                  13.1              Hypersomnia             13.1
# ...                 ...                      ...              ...
# 798175              NaN                      NaN              NaN
# 798176             24.0                 Headache             24.0
# 798177             24.0                      NaN              NaN
# 798178             24.0         Cartilage injury             24.0
# 798179             24.0     Menstruation delayed             24.0
#
#                         SYMPTOM5  SYMPTOMVERSION5
# 0       Injection site urticaria             13.1
# 1                            NaN              NaN
# 2                            NaN              NaN
# 3                       Swelling             13.1
# 4                   Irritability             13.1
# ...                          ...              ...
# 798175                       NaN              NaN
# 798176               Hypersomnia             24.0
# 798177                       NaN              NaN
# 798178              Chondropathy             24.0
# 798179                       NaN              NaN
#
# [798180 rows x 11 columns]

# %%
df3 = pd.read_csv(paththree, low_memory=False)
vax_df = df3.drop_duplicates(subset=['VAERS_ID'], keep='first', ignore_index=True)
vax_df
# Out:
#         VAERS_ID    VAX_TYPE              VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 0         413801         PPV      MERCK & CO. INC.      NaN               1
# 1         413802        HPV4      MERCK & CO. INC.    1312X             UNK
# 2         413803        FLU3           CSL LIMITED   M52108             UNK
# 3         413804         PPV  UNKNOWN MANUFACTURER      NaN               1
# 4         413805  DTAPIPVHIB        SANOFI PASTEUR      NaN               1
# ...          ...         ...                   ...      ...             ...
# 798180   1442854     COVID19       PFIZER\BIONTECH   ER8735               2
# 798181   1442855     COVID19       PFIZER\BIONTECH  EL-0140               1
# 798182   1442856     COVID19       PFIZER\BIONTECH   EW0196               1
# 798183   1442857     COVID19       PFIZER\BIONTECH      NaN               2
# 798184   1442858     COVID19               JANSSEN      NaN             UNK
#
#        VAX_ROUTE VAX_SITE                             VAX_NAME
# 0             IJ       RL                   PNEUMO (PNEUMOVAX)
# 1             IJ      NaN                       HPV (GARDASIL)
# 2             IM       LA       INFLUENZA (SEASONAL) (AFLURIA)
# 3            NaN       RA               PNEUMO (NO BRAND NAME)
# 4            NaN       LL          DTAP + IPV + HIB (PENTACEL)
# ...          ...      ...                                  ...
# 798180        IM       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 798181        IM       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 798182        IM       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 798183        IM       RA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 798184       NaN       RA          COVID19 (COVID19 (JANSSEN))
#
# [798185 rows x 8 columns]
